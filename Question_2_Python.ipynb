# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/sample_data/Q2-Dataset.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... MasVnrArea ExterQual ExterCond Foundation  \
# 0         Lvl    AllPub  ...        196        Gd        TA      PConc
# 1         Lvl    AllPub  ...          0        TA        TA     CBlock
# 2         Lvl    AllPub  ...        162        Gd        TA      PConc
# 3         Lvl    AllPub  ...          0        TA        TA     BrkTil
# 4         Lvl    AllPub  ...        350        Gd        TA      PConc
#
#   BsmtQual BsmtCond BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2
# ...

# %%
ds = df.fillna(method="ffill")
ds
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# ..  ..         ...      ...          ...      ...    ...   ...      ...
# 94  95          60       RL         69.0     9337   Pave  Grvl      IR1
# 95  96          60       RL         69.0     9765   Pave  Grvl      IR2
# 96  97          20       RL         78.0    10264   Pave  Grvl      IR1
# 97  98          20       RL         73.0    10921   Pave  Grvl      Reg
# 98  99          30       RL         85.0    10625   Pave  Grvl      Reg
#
#    LandContour Utilities  ... MasVnrArea ExterQual ExterCond Foundation  \
# ...

# %%
ds = ds.fillna(method="bfill")
ds
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1    2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2    3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3    4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4    5          60       RL         84.0    14260   Pave  Grvl      IR1
# ..  ..         ...      ...          ...      ...    ...   ...      ...
# 94  95          60       RL         69.0     9337   Pave  Grvl      IR1
# 95  96          60       RL         69.0     9765   Pave  Grvl      IR2
# 96  97          20       RL         78.0    10264   Pave  Grvl      IR1
# 97  98          20       RL         73.0    10921   Pave  Grvl      Reg
# 98  99          30       RL         85.0    10625   Pave  Grvl      Reg
#
#    LandContour Utilities  ... MasVnrArea ExterQual ExterCond Foundation  \
# ...

# %%
ds['MasVnrArea']=ds['MasVnrArea'].replace(0,ds['MasVnrArea'].mean())
ds
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1    2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2    3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3    4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4    5          60       RL         84.0    14260   Pave  Grvl      IR1
# ..  ..         ...      ...          ...      ...    ...   ...      ...
# 94  95          60       RL         69.0     9337   Pave  Grvl      IR1
# 95  96          60       RL         69.0     9765   Pave  Grvl      IR2
# 96  97          20       RL         78.0    10264   Pave  Grvl      IR1
# 97  98          20       RL         73.0    10921   Pave  Grvl      Reg
# 98  99          30       RL         85.0    10625   Pave  Grvl      Reg
#
#    LandContour Utilities  ...  MasVnrArea ExterQual ExterCond Foundation  \
# ...

# %%
ds['BsmtFinSF1']=ds['BsmtFinSF1'].replace(0,ds['BsmtFinSF1'].mean())
ds
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1    2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2    3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3    4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4    5          60       RL         84.0    14260   Pave  Grvl      IR1
# ..  ..         ...      ...          ...      ...    ...   ...      ...
# 94  95          60       RL         69.0     9337   Pave  Grvl      IR1
# 95  96          60       RL         69.0     9765   Pave  Grvl      IR2
# 96  97          20       RL         78.0    10264   Pave  Grvl      IR1
# 97  98          20       RL         73.0    10921   Pave  Grvl      Reg
# 98  99          30       RL         85.0    10625   Pave  Grvl      Reg
#
#    LandContour Utilities  ...  MasVnrArea ExterQual ExterCond Foundation  \
# ...

# %%
ds.to_csv("/content/sample_data/Q2-Dataset-modified.csv")
